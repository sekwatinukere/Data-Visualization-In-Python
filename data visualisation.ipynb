# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
steps_walked = [8934, 14902, 3409, 25672, 12300, 2023, 6890]

# %%
plt.plot(steps_walked)
plt.show()

# %% [markdown]
#  { You can call plot() with two input arguments instead of one to determine what data to use for both the x– and y-axes:
# The first argument in plot() corresponds to data you want to use for the x-axis, and the second argument represents the y-axis values. }

# %%
plt.plot(days,steps_walked)
plt.show()

# %%
# { The labels on the x-axis now show the days of the week since these are the values in the list days. }

# %%
# { Customizing Plots }

# %%
plt.plot(days, steps_walked, "o")
plt.show()

# %%
# {  If you’d like to plot markers but keep the line connecting the data points, you can use "o-" as the format string: }

# %%
plt.plot(days, steps_walked, "o-r")

# %%
# { More Variations}

# %%
plt.plot(days, steps_walked, "x-r")

# %%
plt.plot(days, steps_walked, color='red', marker='x', linestyle='--',linewidth=1,markersize=10)

# %%
# { Adding Titles and labels }
# {Titles, X-axis , Y-axis}

# %%
plt.plot(days, steps_walked, "x--r")
plt.title("Step count for the week")
plt.xlabel("Days of the week")
plt.ylabel("Steps Walked")
plt.show()

# %%
# { Adding a second list }

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
steps_walked = [8934, 14902, 3409, 25672, 12300, 2023, 6890]
steps_last_week = [9788, 8710, 5308, 17630, 21309, 4002, 5223]

# %%
plt.plot(days, steps_walked, "o-g")
plt.plot(days, steps_last_week, "v--m")
plt.title("Step count | This week and last week")
plt.xlabel("Days of the week")
plt.ylabel("Steps walked")
plt.grid(True)
plt.legend(["This week", "Last week"])
plt.show()

# %%
# 1. Figure: This is the whole region of space that’s created when you create any figure. The Figure object is the overall object that contains everything else.
# 2. Axes: An Axes object is the object that contains the x-axis and y-axis for a 2D plot. Each Axes object corresponds to a plot or a graph. You can have more than one Axes object in a Figure, as you’ll see later on in this Chapter.
# 3. Axis: An Axis object contains one of the axes, the x-axis or the y-axis for a 2D plot.
# Therefore, a Matplotlib figure is a Figure object which has one or more Axes objects. Each Axes object has two or three Axis object

# %%
# { Creating Subplots}

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1,2)
plt.show()

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
steps_walked = [8934, 14902, 3409, 25672, 12300, 2023, 6890]
steps_last_week = [9788, 8710, 5308, 17630, 21309, 4002, 5223]
fig, axs = plt.subplots(1, 2)
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
plt.show()

# %%
# { Subplot }

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
steps_walked = [8934, 14902, 3409, 25672, 12300, 2023, 6890]
steps_last_week = [9788, 8710, 5308, 17630, 21309, 4002, 5223]
fig, axs = plt.subplots(1, 2)
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
# Plot Bar Chart
axs[1].bar(days, steps_walked)
axs[1].bar(days, steps_last_week)
axs[1].set_title("Step count | This week and last week")
axs[1].set_xlabel("Days of the week")
axs[1].set_ylabel("Steps walked")
axs[1].grid(True)
plt.show()

# %%
# { Customizing Bar Plot }

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
steps_walked = [8934, 14902, 3409, 25672, 12300, 2023, 6890]
steps_last_week = [9788, 8710, 5308, 17630, 21309, 4002, 5223]
fig, axs = plt.subplots(1, 2)
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
 
 # Plot Bar Chart

x_range_current = [-0.2, 0.8, 1.8, 2.8, 3.8, 4.8, 5.8]
x_range_prev = [0.2, 1.2, 2.2, 3.2, 4.2, 5.2, 6.2]
axs[1].bar(x_range_current, steps_walked)
axs[1].bar(x_range_prev, steps_last_week)
axs[1].set_title("Step count | This week and last week")
axs[1].set_xlabel("Days of the week")
axs[1].set_ylabel("Steps walked")
axs[1].grid(True)
plt.show()

# %% [markdown]
# You’re using the numbers 0 to 6 to represent the days of the week. The numbers in x_range_current are shifted by -0.2 from the numbers in the range 0 to 6. The numbers in x_range_previous are shifted by +0.2. Therefore, when you use these values in the two calls to bar(), the bar charts plotted are shifted with respect to each other:

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
# Plot line chart
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
# Plot bar chart
x_range_current = [-0.2, 0.8, 1.8, 2.8, 3.8, 4.8, 5.8]
x_range_previous = [0.2, 1.2, 2.2, 3.2, 4.2, 5.2, 6.2]
axs[1].bar(x_range_current, steps_walked, width=0.4, color="g")
axs[1].bar(x_range_previous, steps_last_week, width=0.4, color="m")
axs[1].set_title("Step count | This week and last week")
axs[1].set_xlabel("Days of the week")
axs[1].set_ylabel("Steps walked")
axs[1].grid(True)
plt.show()

# %%
# { Bar Plot Customization }

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
# Plot line chart
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
# Plot bar chart
x_range_current = [-0.2, 0.8, 1.8, 2.8, 3.8, 4.8, 5.8]
x_range_previous = [0.2, 1.2, 2.2, 3.2, 4.2, 5.2, 6.2]
axs[1].bar(x_range_current, steps_walked, width=0.4)
axs[1].bar(x_range_previous, steps_last_week, width=0.4)
axs[1].set_title("Step count | This week and last week")
axs[1].set_xlabel("Days of the week")
axs[1].set_ylabel("Steps walked")
axs[1].grid(True)
plt.show()

# %% [markdown]
# Although you can see the separate bars because of the shift, the bars are still overlapping. The default width of each bar is still too large. You can change the width of the bars to prevent them from overlapping. Since you shifted each set of bars by 0.2 from the centre, you can set the width of each bar to 0.4. You can also change the colour of the bars so that you’re using the same colour scheme as in the plot on the left-hand side:

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
# Plot line chart
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
# Plot bar chart
x_range_current = [-0.2, 0.8, 1.8, 2.8, 3.8, 4.8, 5.8]
x_range_previous = [0.2, 1.2, 2.2, 3.2, 4.2, 5.2, 6.2]
axs[1].bar(x_range_current, steps_walked, width=0.4, color="g")
axs[1].bar(x_range_previous, steps_last_week, width=0.4, color="m")
axs[1].set_title("Step count | This week and last week")
axs[1].set_xlabel("Days of the week")
axs[1].set_ylabel("Steps walked")
axs[1].grid(True)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))
# Plot line chart
axs[0].plot(days, steps_walked, "o-g")
axs[0].plot(days, steps_last_week, "v--m")
axs[0].set_title("Step count | This week and last week")
axs[0].set_xlabel("Days of the week")
axs[0].set_ylabel("Steps walked")
axs[0].grid(True)
# Plot bar chart
x_range_current = [-0.2, 0.8, 1.8, 2.8, 3.8, 4.8, 5.8]
x_range_previous = [0.2, 1.2, 2.2, 3.2, 4.2, 5.2, 6.2]
axs[1].bar(x_range_current, steps_walked, width=0.4, color="g")
axs[1].bar(x_range_previous, steps_last_week, width=0.4, color="m")
axs[1].set_title("Step count | This week and last week")
axs[1].set_xlabel("Days of the week")
axs[1].set_ylabel("Steps walked")
axs[1].grid(True)
axs[1].set_xticks(range(7))
axs[1].set_xticklabels(days)

# { Figure-wide components }

fig.suptitle("Step Count | This week and Last week")
fig.legend(["This week","Last Week"])

plt.show()

# %% [markdown]
# **BASIC CHART TYPES**

# %%
import pandas as pd

# %%
data = pd.read_csv("tip.csv")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **BAR CHART**

# %%
# { initializing the data }

x = data['day']
y = data['total_bill']

# %%
# { plotting the data }
plt.bar(x, y)

# { Adding title to the plot }
plt.title("Tips Dataset")

# { Adding labels on the y- and x-axis }
plt.ylabel("Total Bill")
plt.xlabel("Day")

plt.show()

# %% [markdown]
# Customization that is available for the Bar Chart –
#
# - color: For the bar faces
# - edgecolor: Color of edges of the bar
# - linewidth: Width of the bar edges
# - width: Width of the bar

# %%
# { Customization }
plt.bar(x, y, color='green', edgecolor='blue',linewidth=2)
# Out:
# <BarContainer object of 244 artists>

# %% [markdown]
# **HISTOGRAM**
#
# A histogram is basically used to represent data provided in a form of some groups. It is a type of bar plot where the X-axis represents the bin ranges while the Y-axis gives information about frequency. The hist() function is used to compute and create histogram of x.
#
#
# Syntax:
#
# matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype=’bar’, align=’mid’, orientation=’vertical’, rwidth=None, log=False, color=None, label=None, stacked=False, \*, data=None, \*\*kwargs)

# %%
# { initialzie the data }
x = data["total_bill"]

# { plotting the data }
plt.hist(x)

# { Adding the title to the plot }
plt.title("Tips Dataset")

# { Adding labels to the y- and x-axis }
plt.ylabel("Frequency")
plt.xlabel("Total Bill")

plt.show()

# %% [markdown]
# Customization that is available for the Histogram –
#
# - bins: Number of equal-width bins
# - color: For changing the face color
# - edgecolor: Color of the edges
# - linestyle: For the edgelines
# - alpha: blending value, between 0 (transparent) and 1 (opaque)

# %%
# { Customization Line }
plt.hist(x, bins=25, color='green', edgecolor='blue',linestyle='--', alpha=0.5)
# Out:
# (array([ 1.,  1., 10., 18., 19., 28., 27., 30., 15., 19., 14., 13.,  8.,
#          7.,  8.,  5.,  6.,  1.,  3.,  4.,  1.,  1.,  1.,  3.,  1.]),
#  array([ 3.07  ,  4.9796,  6.8892,  8.7988, 10.7084, 12.618 , 14.5276,
#         16.4372, 18.3468, 20.2564, 22.166 , 24.0756, 25.9852, 27.8948,
#         29.8044, 31.714 , 33.6236, 35.5332, 37.4428, 39.3524, 41.262 ,
#         43.1716, 45.0812, 46.9908, 48.9004, 50.81  ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# **Scatter Plot**
#
# Scatter plots are used to observe relationships between variables. The scatter() method in the matplotlib library is used to draw a scatter plot.
#
# Syntax:
#
# matplotlib.pyplot.scatter(x_axis_data, y_axis_data, s=None, c=None, marker=None, cmap=None, vmin=None, vmax=None, alpha=None, linewidths=None, edgecolors=None)

# %%
iris_data = pd.read_csv("iris.csv")

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(x = iris_data['SepalLengthCm'],y = [iris_data["PetalLengthCm"]],alpha=1)

plt.title("Scatter Plot")
plt.xlabel('sepal_length')
plt.ylabel('petal_length')

plt.show()

# %% [markdown]
# Customizations that are available for the scatter plot are –
#
# - s: marker size (can be scalar or array of size equal to size of x or y)
# - c: color of sequence of colors for markers
# - marker: marker style
# - linewidths: width of marker border
# - edgecolor: marker border color
# - alpha: blending value, between 0 (transparent) and 1 (opaque)

# %%
# { Customization Line }
plt.scatter(x = iris_data['SepalLengthCm'],y = iris_data['PetalLengthCm'],
            marker='D',alpha=0.5)

# %% [markdown]
# **PIE CHART**
#
# Pie chart is a circular chart used to display only one series of data. The area of slices of the pie represents the percentage of the parts of the data. The slices of pie are called wedges. It can be created using the pie() method.
#
# Syntax:
#
# matplotlib.pyplot.pie(data, explode=None, labels=None, colors=None, autopct=None, shadow=False)

# %%
# { Initialize the data }

cars = ['AUDI', 'BMW', 'FORD','TESLA', 'JAGUAR']
data = [23, 10, 35, 15, 12]

# { plotting the data }
plt.pie(data,labels = cars)

# { Adding title to the plot }
plt.title('Car Data')

plt.show()

# %% [markdown]
# Customizations that are available for the Pie chart are –
#
# - explode: Moving the wedges of the plot
# - autopct: Label the wedge with their numerical value.
# - color: Attribute is used to provide color to the wedges.
# - shadow: Used to create shadow of wedge.

# %%
# { Adding Data }

explode = [0.1, 0.5, 0, 0, 0]

colors = ( "orange", "cyan", "yellow",
          "grey", "green",)

# { Customization Line }
plt.pie(data, labels=cars, explode=explode, autopct='%1.2f%%',
        colors=colors, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1994f6ac470>,
#   <matplotlib.patches.Wedge at 0x1994f6d1100>,
#   <matplotlib.patches.Wedge at 0x1994f6d1d60>,
#   <matplotlib.patches.Wedge at 0x1994f6d2660>,
#   <matplotlib.patches.Wedge at 0x1994f6d2f30>],
#  [Text(0.8693102126702406, 0.8272241257042865, 'AUDI'),
#   Text(-0.4438445885660023, 1.537205900717492, 'BMW'),
#   Text(-1.0784180266553678, -0.2168284109261114, 'FORD'),
#   Text(0.3051431210462195, -1.0568290664427111, 'TESLA'),
#   Text(1.0145187254268326, -0.42514909826826053, 'JAGUAR')],
#  [Text(0.5070976240576403, 0.4825474066608338, '24.21%'),
#   Text(-0.30514315463912656, 1.0568290567432757, '10.53%'),
#   Text(-0.5882280145392914, -0.11827004232333348, '36.84%'),
#   Text(0.16644170238884698, -0.5764522180596606, '15.79%'),
#   Text(0.5533738502328177, -0.2318995081463239, '12.63%')])

# %% [markdown]
# **Saving A Plot**
#
# For saving a plot in a file on storage disk, savefig() method is used. A file can be saved in many formats like .png, .jpg, .pdf, etc.
#
# Syntax:
#
# pyplot.savefig(fname, dpi=None, facecolor=’w’, edgecolor=’w’, orientation=’portrait’, papertype=None, format=None, transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None, metadata=None)

# %%
# { Initializing Data }

year = ['2010', '2002', '2004', '2006', '2008']
production = [25, 15, 35, 30, 10]

# { plotting the bar chart }
plt.bar(year,production, color="red")

# saving the figure
plt.savefig("output.jpg")

# saving the figure by changing parameter values
plt.savefig("output1", facecolor='y', bbox_inches="tight",
            pad_inches=0.3, transparent=True)

# %% [markdown]
# **Plotting in 3D**
#
# Another common requirement in data visualisation in Python is to display 3d plots. You can plot data in 3D using Matplotlib.
#
# The subplot_kw parameter in plt.subplots() allows you to pass keyword parameters into the creation of subplots. In this case, you’re choosing the projection of the plot to be 3D. This creates an Axes3D object. One of its methods is plot_surface() which plots the array Z as a 3D surface. You use the "viridis" colour map.

# %%
import numpy as np
x = np.linspace(-5, 5, 1000)
y = np.linspace(-5, 5, 1000)
X, Y = np.meshgrid(x, y)
Z = (np.sin(X) / X) * (np.sin(Y) / Y)
fig, ax = plt.subplots(subplot_kw={'projection': "3d"})
ax.plot_surface(X, Y, Z, cmap="viridis")
plt.show()
